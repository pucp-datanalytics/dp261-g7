# %% [markdown]
# # Sprint 5: Seguimiento y Registro de Experimentos
#
# Registro ordenado en experiments_log.csv.

# %%
import pandas as pd

log_path = "../experiments_log.csv"
entry = pd.DataFrame([{
    'experiment': 'Stacking_SMOTE_MinMax_Tuned',
    'metric_Recall': 0.5625,
    'metric_AUC': 0.5196,
    'status': 'final_model'
}])

entry.to_csv(log_path, index=False)
print("Logs guardados en experiments_log.csv.")
# Out:
# Logs guardados en experiments_log.csv.
